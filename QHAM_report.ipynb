# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def ratio(datafile):
    datafile['m_n'] = datafile['n_mems']/datafile['n_qubits']
    datafile.sort_values(by=['n_updates', 'm_n'])
    return datafile

# %%
df4 = pd.read_csv('/home/rajarsi/Documents/QuantumML.project/QHAM.report/EXP_ n=[8]_ m=[4, 6, 8, 12, 14, 16]')
df5 = pd.read_csv('/home/rajarsi/Documents/QuantumML.project/QHAM.report/EXP_ n=[5]_ m=[3, 4, 5, 6, 8, 10]')
df8 = pd.read_csv('/home/rajarsi/Documents/QuantumML.project/QHAM.report/EXP_ n=[8]_ m=[4, 6, 8, 12, 14, 16]')
df10 = pd.read_csv('/home/rajarsi/Documents/QuantumML.project/QHAM.report/EXP_ n=[10]_ m=[4, 8, 12, 14, 16]')
df12 = pd.read_csv('/home/rajarsi/Documents/QuantumML.project/QHAM.report/EXP_ n=[12]_ m=[4, 12, 18, 24, 28, 32]')

# %%
frames = [df4,df5,df8,df10,df12]
frames = [ratio(df) for df in frames]
df = pd.concat(frames)
# df

# %%
df
# Out:
#     Unnamed: 0  n_qubits  n_mems  trials  n_updates  correct_majorities  \
# 0            0       8.0     4.0   500.0        8.0               0.536
# 1            1       8.0     4.0   500.0       10.0               0.446
# 2            2       8.0     4.0   500.0       12.0               0.420
# 3            3       8.0     6.0   500.0        8.0               0.376
# 4            4       8.0     6.0   500.0       10.0               0.342
# ..         ...       ...     ...     ...        ...                 ...
# 13          13      12.0    28.0   500.0       18.0               0.020
# 14          14      12.0    28.0   500.0       22.0               0.008
# 15          15      12.0    32.0   500.0       12.0               0.062
# 16          16      12.0    32.0   500.0       18.0               0.010
# 17          17      12.0    32.0   500.0       22.0               0.010
#
#     density accuracy  total accuracy       m_n
# 0           0.769917        0.142119  0.500000
# ...

# %%
plt.figure(figsize=(24,16))
ax = df12[(df12['n_updates']==12.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True)
df10[(df10['n_updates']==10.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True, ax= ax)
df8[(df8['n_updates']==8.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True, ax= ax)
df5[(df5['n_updates']==5.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True, ax= ax)
df4[(df4['n_updates']==8.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True, ax= ax)
plt.legend(['n= 12','n= 10', 'n= 8','n= 5','n= 4'])
plt.title('Density Accuracy vs. m/n ')
#  df12[(df12['n_updates']==18.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True, ax= ax)
#  plt.legend(['n(U)= 18'])
# Out:
# Text(0.5, 1.0, 'Density Accuracy vs. m/n ')

# %%
plt.figure(figsize=(24,16))
ax = df12[(df12['n_updates']==22.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True)
df10[(df10['n_updates']==16.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True, ax= ax)
df8[(df8['n_updates']==12.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True, ax= ax)
df5[(df5['n_updates']==10.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True, ax= ax)
df4[(df4['n_updates']==8.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True, ax= ax)
plt.legend(['n= 12','n= 10', 'n= 8','n= 5','n= 4'])
plt.title('Density Accuracy vs. m/n ')
#  df12[(df12['n_updates']==18.0)].plot.line(xlabel= 'm/n',ylabel='D acc.',x='m_n',y='density accuracy',grid= True,marker= 'o',legend= True, ax= ax)
#  plt.legend(['n(U)= 18'])
# Out:
# Text(0.5, 1.0, 'Density Accuracy vs. m/n ')

# %%
df5
# Out:
#     Unnamed: 0  n_qubits  n_mems  trials  n_updates  correct_majorities  \
# 0            0       5.0     3.0   500.0        5.0               0.632
# 1            1       5.0     3.0   500.0        6.0               0.558
# 2            2       5.0     3.0   500.0        7.0               0.504
# 3            3       5.0     3.0   500.0        8.0               0.472
# 4            4       5.0     3.0   500.0       10.0               0.422
# 5            5       5.0     4.0   500.0        5.0               0.522
# 6            6       5.0     4.0   500.0        6.0               0.518
# 7            7       5.0     4.0   500.0        7.0               0.476
# 8            8       5.0     4.0   500.0        8.0               0.422
# 9            9       5.0     4.0   500.0       10.0               0.368
# 10          10       5.0     5.0   500.0        5.0               0.454
# 11          11       5.0     5.0   500.0        6.0               0.394
# ...

# %%
plt.figure()
ax= df5[(df5['n_mems']== 3.0)].plot.line(xlabel= 'updates',ylabel='D acc.',x= 'n_updates',y='density accuracy',grid= True, marker='o',legend= True)
df5[(df5['n_mems']== 4.0)].plot.line(xlabel= 'updates',ylabel='D acc.',x= 'n_updates',y='density accuracy',grid= True, marker='o',legend= True, ax= ax)
df5[(df5['n_mems']== 5.0)].plot.line(xlabel= 'updates',ylabel='D acc.',x= 'n_updates',y='density accuracy',grid= True, marker='o',legend= True,ax= ax)
df5[(df5['n_mems']== 6.0)].plot.line(xlabel= 'updates',ylabel='D acc.',x= 'n_updates',y='density accuracy',grid= True, marker='o',legend= True,ax= ax)
df5[(df5['n_mems']== 8.0)].plot.line(xlabel= 'updates',ylabel='D acc.',x= 'n_updates',y='density accuracy',grid= True, marker='o',legend= True,ax= ax)
df5[(df5['n_mems']== 10.0)].plot.line(xlabel= 'updates',ylabel='D acc.',x= 'n_updates',y='density accuracy',grid= True, marker='o',legend= True,ax= ax)
plt.title('DensityAccuracy vs. no.of updates | for n= 5')
plt.legend(['m=3','m= 4','m=5','m=6','m=8','m=10'])

# %%
df12.plot(kind= 'line',x='m_n',y='density accuracy',legend= True,marker= 'o')
# Out:
# <AxesSubplot:xlabel='m_n'>
